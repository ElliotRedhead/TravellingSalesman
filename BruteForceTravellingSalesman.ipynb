# %% [markdown]
# Given a list of cities and coordinates for each city, find the shortest path as the crow flies.

# %%
from random import randint
import matplotlib.pyplot as plt
import math

# %%
def generate_city_coordinates(num_cities):
    cities_coordinates = []
    for city in range(num_cities):
        x = randint(0,1000)
        y = randint(0,1000)
        cities_coordinates.append([x,y])
    return cities_coordinates

# %%
cities_coordinates = generate_city_coordinates(7)
print(cities_coordinates)
# Out:
# [[131, 264], [0, 414], [17, 376], [864, 654], [908, 221], [825, 597], [334, 326]]

# %%
x_coords = []
y_coords = []
for coordinate in cities_coordinates:
    x_coords.append(coordinate[0])
    y_coords.append(coordinate[1])
plt.plot(x_coords, y_coords, "ro")
plt.show()

# %%
def shuffle_points(point_a, point_b, point_c):
    original_point_a = point_a[point_b]
    point_a[point_b] = point_a[point_c]
    point_a[point_c] = original_point_a

# %%
def calculate_pythagorean_distance_sum(coordinates_list):
    total_distance = 0
    for n in range(len(coordinates_list)-1):
        distance = ((coordinates_list[n][0] - coordinates_list[n+1][0]) ** 2 + (coordinates_list[n][1] - coordinates_list[n+1][1]) ** 2) ** 0.5
        total_distance += distance
    return total_distance

# %%
iteration = 0
shortest_distance = None
shortest_coordinate_path = []
x_coords = []
y_coords = []
while True:
    point_a = randint(0, len(cities_coordinates)-1)
    point_b = randint(0, len(cities_coordinates)-1)
    shuffle_points(cities_coordinates, point_a, point_b)
    distance = calculate_pythagorean_distance_sum(cities_coordinates)
    if shortest_distance is None | distance < shortest_distance:
        shortest_distance = distance
        # shortest_coordinate_path = cities_coordinates No, references mutating value
        shortest_coordinate_path = cities_coordinates.copy()
        x_coords = []
        y_coords = []
        for coordinate in shortest_coordinate_path:
            x_coords.append(coordinate[0])
            y_coords.append(coordinate[1])
        print(f"Coordinate path: {shortest_coordinate_path} \n Shortest Distance: {shortest_distance}")
        plt.plot(x_coords, y_coords)
    plt.show()
# Out:
# Coordinate path: [[131, 264], [0, 414], [17, 376], [864, 654], [908, 221], [334, 326], [825, 597]]
#  Shortest Distance: 2711.812634378998
# Coordinate path: [[17, 376], [0, 414], [131, 264], [864, 654], [908, 221], [334, 326], [825, 597]]
#  Shortest Distance: 2650.6516091042254
# Coordinate path: [[17, 376], [0, 414], [131, 264], [908, 221], [864, 654], [334, 326], [825, 597]]
#  Shortest Distance: 2638.3062174252846
# Coordinate path: [[17, 376], [0, 414], [131, 264], [334, 326], [864, 654], [908, 221], [825, 597]]
#  Shortest Distance: 1896.6035485882794
# Coordinate path: [[0, 414], [17, 376], [131, 264], [334, 326], [864, 654], [908, 221], [825, 597]]
#  Shortest Distance: 1857.26524188626
# Coordinate path: [[0, 414], [17, 376], [131, 264], [334, 326], [825, 597], [908, 221], [864, 654]]
#  Shortest Distance: 1794.8030053877667
# Coordinate path: [[0, 414], [17, 376], [131, 264], [334, 326], [908, 221], [825, 597], [864, 654]]
#  Shortest Distance: 1451.3403928391142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7ac849f72880> in <module>
#       8     point_b = randint(0, len(cities_coordinates)-1)
#       9     shuffle_points(cities_coordinates, point_a, point_b)
# ---> 10     distance = calculate_pythagorean_distance_sum(cities_coordinates)
#      11     if distance < shortest_distance:
#      12         shortest_distance = distance
#
# <ipython-input-6-80440acf908a> in calculate_pythagorean_distance_sum(coordinates_list)
#       3     for n in range(len(coordinates_list)-1):
#       4         distance = ((coordinates_list[n][0] - coordinates_list[n+1][0]) ** 2 + (coordinates_list[n][1] - coordinates_list[n+1][1]) ** 2) ** 0.5
# ----> 5         total_distance += distance
#       6     return total_distance
#
# KeyboardInterrupt:
